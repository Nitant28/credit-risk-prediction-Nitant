# %%
import os

folder = "credit-risk-Nitant/notebooks"   # corrected folder name

for file in os.listdir(folder):
    if file.endswith(".ipynb"):
        old_path = os.path.join(folder, file)
        new_name = "Nitant-" + file
        new_path = os.path.join(folder, new_name)
        os.rename(old_path, new_path)

print("All notebook files renamed successfully!")
# Out:
# All notebook files renamed successfully!

# %%
import os

folder = "credit-risk-Nitant/notebooks"   # your renamed folder

for file in os.listdir(folder):
    if file.endswith(".ipynb"):
        old_path = os.path.join(folder, file)
        new_name = "Nitant-" + file
        new_path = os.path.join(folder, new_name)
        os.rename(old_path, new_path)

print("All notebook files renamed successfully!")
# Out:
# All notebook files renamed successfully!
